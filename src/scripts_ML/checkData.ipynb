# %%
import pandas as pd
import numpy as np

# %%
main_path = "/home/sebastian/github/SpecialProblem_Salo/drone_irrigation_vrep/src/data_base/paths_energy/feat_pathv12_nuevo.csv"
pd_data = pd.read_csv(main_path)

# %%
pd_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2335 entries, 0 to 2334
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   path_num               2335 non-null   int64
#  1   missing_points         2335 non-null   int64
#  2   teo_point_time         2335 non-null   int64
#  3   sim_drone_time         2335 non-null   float64
#  4   teo_point_dist         2335 non-null   float64
#  5   sim_point_dist         2335 non-null   float64
#  6   teo_Xdist              2335 non-null   float64
#  7   teo_Ydist              2335 non-null   float64
#  8   sim_Xdist              2335 non-null   float64
#  9   sim_Ydist              2335 non-null   float64
#  10  avg_error_target_dist  2335 non-null   float64
#  11  teo_point_vel          2335 non-null   float64
#  12  Energy                 2335 non-null   float64
#  13  avg_energy             2335 non-null   float64
# dtypes: float64(11), int64(3)
# ...

# %%
pd_data.head()
# Out:
#    path_num  missing_points  teo_point_time  sim_drone_time  teo_point_dist  \
# 0         1               7              91       89.300003        5.656854
# 1         1               6              90       86.850006        3.000000
# 2         1               4              70       68.600006        5.000000
# 3         1               3              98       94.499985        3.000000
# 4         1               2              95       91.049988        3.000000
#
#    sim_point_dist  teo_Xdist  teo_Ydist  sim_Xdist  sim_Ydist  \
# 0        5.446446        4.0        4.0   3.851872   3.850145
# 1        3.171659        0.0        3.0   0.537618   3.019579
# 2        4.828957        3.0        4.0   2.877582   3.841778
# 3        3.174537        3.0        0.0   2.962148   0.679134
# 4        2.965050        0.0        3.0   0.399833   2.823458
#
#    avg_error_target_dist  teo_point_vel        Energy     avg_energy
# ...

# %%
eps = 5
pd_strange = pd_data[(pd_data["sim_point_dist"]-pd_data["teo_point_dist"]) > eps]
pd_good = pd_data[(pd_data["sim_point_dist"]-pd_data["teo_point_dist"]) < eps]

# %%
pd_strange.head()
# Out:
#     path_num  missing_points  teo_point_time  sim_drone_time  teo_point_dist  \
# 6          2               8              87       98.400002        9.848858
# 21         4               8              78       89.300003        9.848858
# 27         5               8              73       84.699997       12.727922
# 34         6               8              79       91.099998       10.630146
# 42         7               8              99      109.500000        6.082763
#
#     sim_point_dist  teo_Xdist  teo_Ydist  sim_Xdist  sim_Ydist  \
# 6        27.553946        9.0        4.0  24.934430  11.712182
# 21       27.853925        9.0        4.0  22.737664  15.649199
# 27       40.673401        9.0        9.0  28.762135  28.488719
# 34       23.663586        7.0        8.0  18.642441  13.717880
# 42       15.737917        1.0        6.0   6.730322  13.797989
#
#     avg_error_target_dist  teo_point_vel        Energy     avg_energy
# ...

# %%
pd_good.head()
# Out:
#    path_num  missing_points  teo_point_time  sim_drone_time  teo_point_dist  \
# 0         1               7              91       89.300003        5.656854
# 1         1               6              90       86.850006        3.000000
# 2         1               4              70       68.600006        5.000000
# 3         1               3              98       94.499985        3.000000
# 4         1               2              95       91.049988        3.000000
#
#    sim_point_dist  teo_Xdist  teo_Ydist  sim_Xdist  sim_Ydist  \
# 0        5.446446        4.0        4.0   3.851872   3.850145
# 1        3.171659        0.0        3.0   0.537618   3.019579
# 2        4.828957        3.0        4.0   2.877582   3.841778
# 3        3.174537        3.0        0.0   2.962148   0.679134
# 4        2.965050        0.0        3.0   0.399833   2.823458
#
#    avg_error_target_dist  teo_point_vel        Energy     avg_energy
# ...

# %%
pd_strange.describe()
# Out:
#          path_num  missing_points  teo_point_time  sim_drone_time  \
# count  303.000000      303.000000       303.00000      303.000000
# mean   162.669967        7.851485        83.69967      157.626733
# std     93.550160        0.383072         8.81406       66.626848
# min      2.000000        7.000000        70.00000       81.349998
# 25%     81.500000        8.000000        76.00000      104.025002
# 50%    161.000000        8.000000        83.00000      133.550003
# 75%    244.000000        8.000000        92.00000      207.424995
# max    326.000000        9.000000        99.00000      408.350006
#
#        teo_point_dist  sim_point_dist   teo_Xdist   teo_Ydist   sim_Xdist  \
# count      303.000000      303.000000  303.000000  303.000000  303.000000
# mean         8.505599       25.021383    5.488449    5.716172   16.659961
# std          3.178153        7.764366    3.156885    3.116709    7.916153
# min          1.414214        7.533399    0.000000    0.000000    3.044303
# ...

# %%
pd_good.describe()
# Out:
#           path_num  missing_points  teo_point_time  sim_drone_time  \
# count  2032.000000     2032.000000     2032.000000     2032.000000
# mean    170.346949        3.942421       84.677657      141.492569
# std      95.084358        2.003476        8.641838       66.061890
# min       1.000000        1.000000       70.000000       64.100037
# 25%      88.000000        2.000000       77.000000       89.437508
# 50%     174.000000        4.000000       85.000000      113.199997
# 75%     254.000000        6.000000       92.000000      191.250031
# max     326.000000        8.000000       99.000000      490.649902
#
#        teo_point_dist  sim_point_dist    teo_Xdist    teo_Ydist    sim_Xdist  \
# count     2032.000000     2032.000000  2032.000000  2032.000000  2032.000000
# mean         4.576175        4.678029     2.961614     2.763287     3.058915
# std          2.919410        2.943587     2.662633     2.443366     2.590222
# ...
