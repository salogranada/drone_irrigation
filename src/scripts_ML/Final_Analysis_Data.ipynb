# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Paths

# %%
main_path_energy ='../data_base/paths_energy/'
main_path_total_energy = '../data_base/paths_totals/'
main_path_turns = "/home/sebastian/Desktop/"

energy_path11_pd = pd.read_csv(main_path_energy + 'feat_pathv11_TM.csv')
energy_path12_pd = pd.read_csv(main_path_energy + 'feat_pathv12_TM.csv')
energy_path13_pd = pd.read_csv(main_path_energy + 'feat_pathv13_TM.csv')

energy_path_list = [energy_path11_pd,energy_path12_pd,energy_path13_pd]
complete_energy_pd = pd.concat(energy_path_list)

total_path11_pd = pd.read_csv(main_path_total_energy + 'totalF_pathv11.csv')
total_path12_pd = pd.read_csv(main_path_total_energy + 'totalF_pathv12.csv')
total_path13_pd = pd.read_csv(main_path_total_energy + 'totalF_pathv13.csv')

total_path_list = [total_path11_pd,total_path12_pd,total_path13_pd]
complete_total_pd = pd.concat(total_path_list)

#We are not going to use the 'turns' feature.
# turns_path11_pd = pd.read_csv(main_path_turns + 'distanceTurn_v11.csv')
# turns_path12_pd = pd.read_csv(main_path_turns + 'distanceTurn_v12.csv')
# turns_path13_pd = pd.read_csv(main_path_turns + 'distanceTurn_v13.csv')

# turns_list = [turns_path11_pd,turns_path12_pd,turns_path13_pd]

# %%
print(f'Initial shape path_v11, energy = {energy_path11_pd.shape}, total_energy = {total_path11_pd.shape}')
print(f'Initial shape path_v12, energy = {energy_path12_pd.shape}, total_energy = {total_path12_pd.shape}')
print(f'Initial shape path_v13, energy = {energy_path13_pd.shape}, total_energy = {total_path13_pd.shape}')
print(f'....................,    total = {complete_energy_pd.shape},      total = {complete_total_pd.shape}')
# Out:
# Initial shape path_v11, energy = (595, 17), total_energy = (192, 7)
# Initial shape path_v12, energy = (3902, 17), total_energy = (527, 7)
# Initial shape path_v13, energy = (178, 17), total_energy = (65, 7)
# ....................,    total = (4675, 17),      total = (784, 7)

# %%
complete_energy_pd.reset_index(inplace=True)
complete_total_pd.reset_index(inplace=True)

# %% [markdown]
# ### Data after some adjustment

# %%
complete_energy_pd.head()
# Out:
#    index  path_num  missing_points  teo_point_time  sim_drone_time  \
# 0      0         1               3             190      188.400009
# 1      1         1               2             233      232.250000
# 2      2         2               3             248      258.149994
# 3      3         2               2             157      155.999969
# 4      4         2               1             236      235.700043
#
#    teo_point_dist  sim_point_dist  teo_Xdist  teo_Ydist  sim_Xdist  sim_Ydist  \
# 0       14.142136       13.897487       10.0       10.0   9.827389   9.825728
# 1       12.727922       12.899505        9.0        9.0   9.113116   9.116838
# 2       23.323808       26.085592       20.0       12.0  21.910483  14.002723
# 3        8.000000        8.347981        0.0        8.0   1.022886   8.040361
# 4       19.235384       19.229592        3.0       19.0   2.982061  18.982881
#
#    avg_error_target_dist  teo_point_vel  teo_Xvel  teo_Yvel  avg_tankMass  \
# ...

# %%
eps = 5
complete_energy_pd = complete_energy_pd[(complete_energy_pd['sim_point_dist']-complete_energy_pd['teo_point_dist']) < eps]
print(f'new shape of complete_energy_pd = {complete_energy_pd.shape}')
# Out:
# new shape of complete_energy_pd = (3957, 18)

# %% [markdown]
# ### Correlation analysis

# %% [markdown]
# #### discret_energy_analysis - All data

# %%
complete_energy_analysis = complete_energy_pd.drop(columns=["index","missing_points","path_num","sim_drone_time","sim_point_dist","sim_Xdist","sim_Ydist","avg_error_target_dist"],axis=1)
complete_energy_analysis.corr()
# Out:
#                 teo_point_time  teo_point_dist  teo_Xdist  teo_Ydist  \
# teo_point_time        1.000000        0.391562   0.278360   0.322280
# teo_point_dist        0.391562        1.000000   0.782674   0.789044
# teo_Xdist             0.278360        0.782674   1.000000   0.282103
# teo_Ydist             0.322280        0.789044   0.282103   1.000000
# teo_point_vel        -0.043470        0.850422   0.689632   0.655988
# teo_Xvel             -0.065148        0.703255   0.756220   0.380414
# teo_Yvel             -0.020955        0.728794   0.412371   0.748183
# avg_tankMass         -0.171736       -0.065473  -0.036570  -0.060976
# Energy                0.772120        0.416357   0.302904   0.346593
# avg_energy            0.788712        0.452685   0.331119   0.373403
#
#                 teo_point_vel  teo_Xvel  teo_Yvel  avg_tankMass    Energy  \
# teo_point_time      -0.043470 -0.065148 -0.020955     -0.171736  0.772120
# ...

# %% [markdown]
# #### Discrete energy analysis - path v11

# %%
energy_path11_analysis = energy_path11_pd.drop(columns=["missing_points","path_num","sim_drone_time","sim_point_dist","sim_Xdist","sim_Ydist","avg_error_target_dist"],axis=1)
energy_path11_analysis.corr()
# Out:
#                 teo_point_time  teo_point_dist  teo_Xdist  teo_Ydist  \
# teo_point_time        1.000000       -0.007832  -0.001727  -0.000088
# teo_point_dist       -0.007832        1.000000   0.736444   0.759639
# teo_Xdist            -0.001727        0.736444   1.000000   0.172452
# teo_Ydist            -0.000088        0.759639   0.172452   1.000000
# teo_point_vel        -0.415365        0.876602   0.651941   0.657315
# teo_Xvel             -0.313027        0.698824   0.813988   0.285286
# teo_Yvel             -0.356182        0.717927   0.275666   0.806374
# avg_tankMass          0.040706        0.072073   0.063083   0.040671
# Energy                0.580405        0.106441   0.081900   0.097260
# avg_energy            0.618609        0.122168   0.090602   0.112769
#
#                 teo_point_vel  teo_Xvel  teo_Yvel  avg_tankMass    Energy  \
# teo_point_time      -0.415365 -0.313027 -0.356182      0.040706  0.580405
# ...

# %%
energy_path11_analysis = energy_path11_pd[(energy_path11_pd['sim_point_dist']-energy_path11_pd['teo_point_dist']) < eps]
energy_path11_analysis = energy_path11_analysis.drop(columns=["missing_points","path_num","sim_drone_time","sim_point_dist","sim_Xdist","sim_Ydist","avg_error_target_dist"],axis=1)
energy_path11_analysis.corr()
# Out:
#                 teo_point_time  teo_point_dist  teo_Xdist  teo_Ydist  \
# teo_point_time        1.000000       -0.024612  -0.043691   0.015328
# teo_point_dist       -0.024612        1.000000   0.713956   0.751460
# teo_Xdist            -0.043691        0.713956   1.000000   0.130464
# teo_Ydist             0.015328        0.751460   0.130464   1.000000
# teo_point_vel        -0.404160        0.890462   0.660920   0.643685
# teo_Xvel             -0.343153        0.704020   0.751186   0.336263
# teo_Yvel             -0.337333        0.756134   0.352092   0.749570
# avg_tankMass          0.049750       -0.008155   0.001469  -0.022525
# Energy                0.582497        0.101830   0.066679   0.107651
# avg_energy            0.627835        0.109022   0.066407   0.117928
#
#                 teo_point_vel  teo_Xvel  teo_Yvel  avg_tankMass    Energy  \
# teo_point_time      -0.404160 -0.343153 -0.337333      0.049750  0.582497
# ...

# %% [markdown]
# #### Discrete energy analysis - path v12

# %%
energy_path12_analysis = energy_path12_pd.drop(columns=["missing_points","path_num","sim_drone_time","sim_point_dist","sim_Xdist","sim_Ydist","avg_error_target_dist"],axis=1)
energy_path12_analysis.corr()
# Out:
#                 teo_point_time  teo_point_dist  teo_Xdist  teo_Ydist  \
# teo_point_time        1.000000       -0.023230  -0.001498  -0.035298
# teo_point_dist       -0.023230        1.000000   0.775958   0.768483
# teo_Xdist            -0.001498        0.775958   1.000000   0.240645
# teo_Ydist            -0.035298        0.768483   0.240645   1.000000
# teo_point_vel        -0.179346        0.982318   0.758894   0.759299
# teo_Xvel             -0.150512        0.832320   0.873647   0.429665
# teo_Yvel             -0.158069        0.824496   0.424637   0.868568
# avg_tankMass         -0.032313        0.069530   0.059271   0.049511
# Energy                0.329453        0.284511   0.219159   0.214013
# avg_energy            0.331891        0.321427   0.248111   0.242810
#
#                 teo_point_vel  teo_Xvel  teo_Yvel  avg_tankMass    Energy  \
# teo_point_time      -0.179346 -0.150512 -0.158069     -0.032313  0.329453
# ...

# %%
energy_path12_analysis = energy_path12_pd[(energy_path12_pd['sim_point_dist']-energy_path12_pd['teo_point_dist']) < eps]
energy_path12_analysis = energy_path12_analysis.drop(columns=["missing_points","path_num","sim_drone_time","sim_point_dist","sim_Xdist","sim_Ydist","avg_error_target_dist"],axis=1)
energy_path12_analysis.corr()
# Out:
#                 teo_point_time  teo_point_dist  teo_Xdist  teo_Ydist  \
# teo_point_time        1.000000       -0.001124   0.014248  -0.011382
# teo_point_dist       -0.001124        1.000000   0.767708   0.736895
# teo_Xdist             0.014248        0.767708   1.000000   0.186562
# teo_Ydist            -0.011382        0.736895   0.186562   1.000000
# teo_point_vel        -0.156632        0.982504   0.751497   0.726151
# teo_Xvel             -0.137707        0.848969   0.837409   0.444887
# teo_Yvel             -0.131887        0.823932   0.443912   0.819064
# avg_tankMass         -0.032982        0.046457   0.043206   0.026902
# Energy                0.353133        0.246031   0.181865   0.181830
# avg_energy            0.357360        0.281179   0.209303   0.207820
#
#                 teo_point_vel  teo_Xvel  teo_Yvel  avg_tankMass    Energy  \
# teo_point_time      -0.156632 -0.137707 -0.131887     -0.032982  0.353133
# ...

# %% [markdown]
# #### Discrete energy analysis - path v13

# %%
energy_path13_analysis = energy_path13_pd.drop(columns=["missing_points","path_num","sim_drone_time","sim_point_dist","sim_Xdist","sim_Ydist","avg_error_target_dist"],axis=1)
energy_path13_analysis.corr()
# Out:
#                 teo_point_time  teo_point_dist  teo_Xdist  teo_Ydist  \
# teo_point_time        1.000000       -0.003396   0.008151   0.007039
# teo_point_dist       -0.003396        1.000000   0.744639   0.720527
# teo_Xdist             0.008151        0.744639   1.000000   0.118456
# teo_Ydist             0.007039        0.720527   0.118456   1.000000
# teo_point_vel        -0.590488        0.686981   0.497075   0.499895
# teo_Xvel             -0.474651        0.583754   0.734637   0.144503
# teo_Yvel             -0.477635        0.566542   0.146386   0.696286
# avg_tankMass         -0.037664        0.241286   0.164200   0.222127
# Energy                0.991186        0.040676   0.037324   0.043617
# avg_energy            0.994176        0.041388   0.042108   0.038519
#
#                 teo_point_vel  teo_Xvel  teo_Yvel  avg_tankMass    Energy  \
# teo_point_time      -0.590488 -0.474651 -0.477635     -0.037664  0.991186
# ...

# %%
energy_path13_analysis = energy_path13_pd[(energy_path13_pd['sim_point_dist']-energy_path13_pd['teo_point_dist']) < eps]
energy_path13_analysis = energy_path13_analysis.drop(columns=["missing_points","path_num","sim_drone_time","sim_point_dist","sim_Xdist","sim_Ydist","avg_error_target_dist"],axis=1)
energy_path13_analysis.corr()
# Out:
#                 teo_point_time  teo_point_dist  teo_Xdist  teo_Ydist  \
# teo_point_time        1.000000        0.053175   0.075121   0.030556
# teo_point_dist        0.053175        1.000000   0.750770   0.656511
# teo_Xdist             0.075121        0.750770   1.000000   0.044504
# teo_Ydist             0.030556        0.656511   0.044504   1.000000
# teo_point_vel        -0.556721        0.674472   0.443349   0.479674
# teo_Xvel             -0.426077        0.588477   0.705560   0.106297
# teo_Yvel             -0.450015        0.498437   0.073727   0.644370
# avg_tankMass         -0.032057        0.190849   0.140136   0.177808
# Energy                0.991239        0.079357   0.090516   0.052823
# avg_energy            0.993367        0.083417   0.104663   0.042190
#
#                 teo_point_vel  teo_Xvel  teo_Yvel  avg_tankMass    Energy  \
# teo_point_time      -0.556721 -0.426077 -0.450015     -0.032057  0.991239
# ...

# %% [markdown]
# #### Complete energy analysis

# %%
complete_total_analysis = complete_total_pd.drop(columns=['index','path_num'],axis=1)
complete_total_analysis.corr()
# Out:
#                 teo_path_dist  teo_path_Xdist  teo_path_Ydist  teo_path_time  \
# teo_path_dist        1.000000        0.800225        0.807580       0.183023
# teo_path_Xdist       0.800225        1.000000        0.340536       0.135036
# teo_path_Ydist       0.807580        0.340536        1.000000       0.151883
# teo_path_time        0.183023        0.135036        0.151883       1.000000
# avg_path_vel         0.963941        0.772763        0.779925      -0.065329
# energy               0.309418        0.223192        0.265219      -0.014806
#
#                 avg_path_vel    energy
# teo_path_dist       0.963941  0.309418
# teo_path_Xdist      0.772763  0.223192
# teo_path_Ydist      0.779925  0.265219
# teo_path_time      -0.065329 -0.014806
# avg_path_vel        1.000000  0.322955
# energy              0.322955  1.000000
